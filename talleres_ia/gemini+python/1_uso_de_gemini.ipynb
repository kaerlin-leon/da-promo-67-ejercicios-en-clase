# %%
import google.generativeai as genai
API_KEY = "AIzaSyA1ptyuM8jrjV0fd33CWumA6Jd3N-Bwr_o"  # pon aquí tu key

genai.configure(api_key=API_KEY)
GEMINI_MODEL = "gemini-2.5-flash"

# %%
model = genai.GenerativeModel(GEMINI_MODEL)
response = model.generate_content(
    [
        {"role": "user", "parts": "Dime la poblacion de españa"}
    ]
)

# %%
response.text
# Out:
# 'La población oficial de España, según los datos del Instituto Nacional de Estadística (INE) a 1 de enero de 2024, era de **48.592.909 personas**.\n\nEs importante recordar que estas cifras varían ligeramente a diario debido a nacimientos, defunciones y movimientos migratorios, pero este es el dato oficial más reciente.'
