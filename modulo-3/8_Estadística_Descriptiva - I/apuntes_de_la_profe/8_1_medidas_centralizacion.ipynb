# %% [markdown]
# # Estadística Descriptiva

# %% [markdown]
# ## Objetivos de la estadística descriptiva
# - Resumen de datos
# - Viusalización de datos
# - Identificación de valores atípicos
# - Exploración de relaciones

# %% [markdown]
# ## Tipos de medidas en estadística descriptiva
#
# ![](./assets/tipos_medidas.png)

# %%
# importamos las librerías que necesitamos

# Tratamiento de datos
# -----------------------------------------------------------------------
import pandas as pd
import numpy as np

# Visualización
# ------------------------------------------------------------------------------
import matplotlib.pyplot as plt
import seaborn as sns

# Evaluar linealidad de las relaciones entre las variables
# ------------------------------------------------------------------------------
from scipy.stats import shapiro, kstest

# Configuración
# -----------------------------------------------------------------------
pd.set_option('display.max_columns', None) # para poder visualizar todas las columnas de los DataFrames

# Gestión de los warnings
# -----------------------------------------------------------------------
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("./files/bank-additional_clean.csv", index_col = 0)

df.head()
# Out:
#    income  kidhome  teenhome dt_customer  numwebvisitsmonth  \
# 0  161770        1         0  2012-04-04                 29
# 1   85477        1         1  2012-12-30                  7
# 2  147233        1         1  2012-02-02                  5
# 3  121393        1         2  2012-12-21                 29
# 4   63164        1         2  2012-06-20                 20
#
#                                      id   age        job  marital  \
# 0  089b39d8-e4d0-461b-87d4-814d71e0e079   NaN  housemaid  married
# 1  e9d37224-cb6f-4942-98d7-46672963d097  57.0   services  married
# 2  3f9f49b5-e410-4948-bf6e-f9244f04918b  37.0   services  married
# 3  9991fafb-4447-451a-8be2-b0df6098d13e  40.0     admin.  married
# 4  eca60b76-70b6-4077-80ba-bc52e8ebb0eb  56.0   services  married
#
#      education default housing loan    contact  duration  campaign  pdays  \
# 0     basic 4y      No      No   No  telephone       261         1    NaN
# ...

# %% [markdown]
# # VARIABLES NUMÉRICAS

# %% [markdown]
# # Medidas de Centralización

# %%
# Medidas centrales para la variable 'income'

media_ingresos = df['income'].mean()
print(f"La media de los ingresos de los clientes es: {np.round(media_ingresos, 2)}")

mediana_ingresos = df['income'].median()
print(f"La mediana de los ingresos de los clientes es: {np.round(mediana_ingresos, 2)}")

moda_ingresos = df['income'].mode()[0]
print(f"La moda de los ingresos  es:  {np.round(moda_ingresos, 2)}")
# Out:
# La media de los ingresos de los clientes es: 93241.2
# La mediana de los ingresos de los clientes es: 93050.5
# La moda de los ingresos  es:  40655

# %% [markdown]
# **Entonces, ¿Cuál es la diferencia entre media y mediana?**
#
# 1. **Media de los Ingresos:** La media de los ingresos de los clientes es aproximadamente 93241.2$
# Esto significa que si sumamos todos los ingresos de los clientes y luego dividimos ese total por la cantidad de clientes, obtendríamos alrededor de 93241.2$.
# Es como si estuviéramos repartiendo equitativamente el dinero entre todos los clientes, y cada uno recibiría alrededor de 93241.2 $.
#
# 2. **Mediana de los Ingresos:** La mediana de los ingresos de los clientes es aproximadamente 93050.5$.
# Imagina que hacemos una lista de todos los ingresos de los clientes en orden de menor a mayor. Luego, encontramos el ingreso que está justo en el medio de la lista. Ese valor es la mediana. En este caso, la mediana es 93050.5$. Esto significa que la mitad de los clientes tiene ingresos menores o iguales a 93050.5$,
# y la otra mitad tiene ingresos mayores o iguales a esa cantidad.
#
# En resumen, la **media** es el promedio de todos los ingresos y puede verse afectada por valores extremos, mientras que la **mediana** es el ingreso que se encuentra justo en el medio cuando los ingresos se ordenan, y no se ve influenciada por valores extremos. Ambas medidas son importantes para entender la distribución de los ingresos de los clientes.

# %%
# Visualizamos estas medidas con un histograma
print(f"Media: {media_ingresos}")
print(f"Mediana: {mediana_ingresos}")
print(f"Moda: {moda_ingresos}")

# Visualización: Histograma con la media y la mediana
sns.histplot(df['income'], bins=20)
plt.axvline(media_ingresos, color='red', linestyle='dashed', linewidth=2, label=f'Media: {media_ingresos}')
plt.axvline(mediana_ingresos, color='green', linestyle='dashed', linewidth=2, label=f'Mediana: {mediana_ingresos}')
plt.axvline(moda_ingresos, color='blue', linestyle='dashed', linewidth=2, label=f'Moda: {moda_ingresos}')

plt.title('Distribución, Media y Mediana')
plt.legend()
plt.show()
# Out:
# Media: 93241.20006976744
# Mediana: 93050.5
# Moda: 40655

# %% [markdown]
# **Entonces, ¿Cuál es la diferencia entre media y mediana?**
#
# 1. **Media de los Ingresos:** La media de los ingresos de los clientes es aproximadamente 93241.2$
# Esto significa que si sumamos todos los ingresos de los clientes y luego dividimos ese total por la cantidad de clientes, obtendríamos alrededor de 93241.2$.
# Es como si estuviéramos repartiendo equitativamente el dinero entre todos los clientes, y cada uno recibiría alrededor de 93241.2 $.
#
# 2. **Mediana de los Ingresos:** La mediana de los ingresos de los clientes es aproximadamente 93050.5$.
# Imagina que hacemos una lista de todos los ingresos de los clientes en orden de menor a mayor. Luego, encontramos el ingreso que está justo en el medio de la lista. Ese valor es la mediana. En este caso, la mediana es 93050.5$. Esto significa que la mitad de los clientes tiene ingresos menores o iguales a 93050.5$,
# y la otra mitad tiene ingresos mayores o iguales a esa cantidad.
#
# En resumen, la **media** es el promedio de todos los ingresos y puede verse afectada por valores extremos, mientras que la **mediana** es el ingreso que se encuentra justo en el medio cuando los ingresos se ordenan, y no se ve influenciada por valores extremos. Ambas medidas son importantes para entender la distribución de los ingresos de los clientes.

# %%
# Medidas centrales para la variable 'age'

media_age = df['age'].mean()
print(f"La media de la edad de los clientes es: {np.round(media_age, 2)}")

mediana_age = df['age'].median()
print(f"La mediana de la edad de los clientes es: {np.round(mediana_age, 2)}")

moda_age = df['age'].mode()[0]
print(f"La moda de la edad de los clientes es:  {np.round(moda_age, 2)}")
# Out:
# La media de la edad de los clientes es: 39.98
# La mediana de la edad de los clientes es: 38.0
# La moda de la edad de los clientes es:  31.0

# %%
# Visualizamos estas medidas con un histograma
print(f"Media: {media_age}")
print(f"Mediana: {mediana_age}")
print(f"Moda: {moda_age}")

# Visualización: Histograma con la media y la mediana
sns.histplot(df['age'], bins=20)
plt.axvline(media_age, color='red', linestyle='dashed', linewidth=2, label=f'Media: {media_age}')
plt.axvline(mediana_age, color='green', linestyle='dashed', linewidth=2, label=f'Mediana: {mediana_age}')
plt.axvline(moda_age, color='blue', linestyle='dashed', linewidth=2, label=f'Moda: {moda_age}')

plt.title('Distribución, Media y Mediana')
plt.legend()
plt.show()
# Out:
# Media: 39.97711193241816
# Mediana: 38.0
# Moda: 31.0

# %%
# Crear el Boxplot para 'income'

plt.figure(figsize=(10, 6))
sns.boxplot(x=df['income'])

# Dibujar líneas para la media, mediana y moda
plt.axvline(media_ingresos, color='red', linestyle='dashed', linewidth=2, label=f'Media: {media_ingresos}')
plt.axvline(mediana_ingresos, color='green', linestyle='dashed', linewidth=2, label=f'Mediana: {mediana_ingresos}')
plt.axvline(moda_ingresos, color='blue', linestyle='dashed', linewidth=2, label=f'Moda: {moda_ingresos}')

# Añadir leyenda y título
plt.legend()
plt.title('Boxplot con Media, Mediana y Moda')

# Mostrar el gráfico
plt.show()

# %%
# Crear el Boxplot para 'age'

plt.figure(figsize=(10, 6))
sns.boxplot(x=df['age'])

# Dibujar líneas para la media, mediana y moda
plt.axvline(media_age, color='red', linestyle='dashed', linewidth=2, label=f'Media: {media_age}')
plt.axvline(mediana_age, color='green', linestyle='dashed', linewidth=2, label=f'Mediana: {mediana_age}')
plt.axvline(moda_age, color='blue', linestyle='dashed', linewidth=2, label=f'Moda: {moda_age}')

# Añadir leyenda y título
plt.legend()
plt.title('Boxplot con Media, Mediana y Moda')

# Mostrar el gráfico
plt.show()

# %% [markdown]
# ### Resumen:
# 1. Calcular las medidas de centralización
# 2. Visualizar con histograma y boxplot añadiendo las líneas de medidas de centralización
# 3. Extraer conclusiones

# %%
# Visualizaciones para 'income'

fig, axes = plt.subplots(1, 2, figsize=(15, 6))

# Visualización: Histograma con la media y la mediana
sns.histplot(df['income'], bins=20, ax=axes[0])
axes[0].axvline(media_ingresos, color='red', linestyle='dashed', linewidth=2, label=f'Media: {media_ingresos}')
axes[0].axvline(mediana_ingresos, color='green', linestyle='dashed', linewidth=2, label=f'Mediana: {mediana_ingresos}')
axes[0].axvline(moda_ingresos, color='blue', linestyle='dashed', linewidth=2, label=f'Moda: {moda_ingresos}')

axes[0].legend()
axes[0].set_title('Histograma con Media, Mediana y Moda')


# Crear el Boxplot para

plt.figure(figsize=(10, 6))
sns.boxplot(x=df['income'], ax=axes[1])

# Dibujar líneas para la media, mediana y moda
axes[1].axvline(media_ingresos, color='red', linestyle='dashed', linewidth=2, label=f'Media: {media_ingresos}')
axes[1].axvline(mediana_ingresos, color='green', linestyle='dashed', linewidth=2, label=f'Mediana: {mediana_ingresos}')
axes[1].axvline(moda_ingresos, color='blue', linestyle='dashed', linewidth=2, label=f'Moda: {moda_ingresos}')

axes[1].legend()
axes[1].set_title('Boxplot con Media, Mediana y Moda')

# Mostrar el gráfico
plt.tight_layout()
plt.show()

# %%
# Visualizaciones para 'age'

fig, axes = plt.subplots(1, 2, figsize=(15, 6))

# Visualización: Histograma con la media y la mediana
sns.histplot(df['age'], bins=20, ax=axes[0])
axes[0].axvline(media_age, color='red', linestyle='dashed', linewidth=2, label=f'Media: {media_age}')
axes[0].axvline(mediana_age, color='green', linestyle='dashed', linewidth=2, label=f'Mediana: {mediana_age}')
axes[0].axvline(moda_age, color='blue', linestyle='dashed', linewidth=2, label=f'Moda: {moda_age}')

axes[0].legend()
axes[0].set_title('Histograma con Media, Mediana y Moda')


# Crear el Boxplot para

plt.figure(figsize=(10, 6))
sns.boxplot(x=df['age'], ax=axes[1])

# Dibujar líneas para la media, mediana y moda
axes[1].axvline(media_age, color='red', linestyle='dashed', linewidth=2, label=f'Media: {media_age}')
axes[1].axvline(mediana_age, color='green', linestyle='dashed', linewidth=2, label=f'Mediana: {mediana_age}')
axes[1].axvline(moda_age, color='blue', linestyle='dashed', linewidth=2, label=f'Moda: {moda_age}')

axes[1].legend()
axes[1].set_title('Boxplot con Media, Mediana y Moda')

# Mostrar el gráfico
plt.tight_layout()
plt.show()

# %% [markdown]
# # ¿Cómo interpretar estas medidas juntas?
# Comparar media y mediana es una forma muy potente de entender la forma de una distribución, sobre todo si hay valores extremos (outliers).
#
# ![](./assets/medidas_centralizacion_juntas.png)
