# %% [markdown]
# # ETL
# - E: Extract
# - T: Transform
# - L: Load

# %%
import pandas as pd
import mysql.connector 
from mysql.connector import  Error

# %%
## Extract (leer de un fichero, llamar a un api, web scrapping,  obtener info de una bd)
clientes = pd.read_csv('files/clientes.csv', index_col=0)
ventas = pd.read_csv('files/ventas.csv')

# %%
clientes.head()
# Out:
#     first_name last_name                         email  gender  \
# id
# 1        Cheri  Dunsmore      cdunsmore0@instagram.com  Female
# 2         Hunt  Bartomeu         hbartomeu1@nsw.gov.au    Male
# 3   Michaeline   Paynton            mpaynton2@narod.ru  Female
# 4       Filmer    Eirwin            feirwin3@intel.com     NaN
# 5       Tanhya   Lubbock  tlubbock4@huffingtonpost.com  Female
#
#                            City Country                   Address
# id
# 1             Palma De Mallorca   Spain  076 Rockefeller Crossing
# 2                          Lugo   Spain        0046 Utah Junction
# 3                           NaN   Spain          0 Corry Crossing
# 4                          Leon   Spain       5 American Ash Road
# 5   Hospitalet De Llobregat, L'   Spain         9289 Merry Circle

# %%
ventas.head()
# Out:
#    ID_Cliente ID_Producto Fecha_Venta  Cantidad  Total
# 0         723          A1  2023-11-22         2  17.98
# 1         498          C3  2023-11-21         1   5.49
# 2         121          D4  2023-11-20         3  32.97
# 3         885         L12  2023-11-19         1   6.49
# 4         347         Q17  2023-11-18         2   7.98

# %%
## Transformacion (quitar nulos, calcular categorias, convertir tipo de datos, cambiar nombre de columnas)
clientes.columns = clientes.columns.str.lower()
ventas.columns = ventas.columns.str.lower()

# %%
# LOAD: carga de datos
try: 
    connection = mysql.connector.connect(
        host= '127.0.0.1',
        user= 'root',
        password= '',
        database = 'bd_etl'
    )
    print('conexion exitosa')
except Error as e:
    print(e)


## crear las tablas
## insertar los datos
# Out:
# conexion exitosa

# %% [markdown]
# ### ETL en funciones

# %%
import pandas as pd
import mysql.connector 
from mysql.connector import  Error

## configuracion de la bases de datos
host= '127.0.0.1'
user= 'root'
password= ''
database = 'bd_etl'

def extract_data(file_path):
    print(f'Extrayendo data de {file_path}')
    data = pd.read_csv(file_path)
    print(data.head())
    return data

def transform_data(data):
    print('Transformando')
    data = data.dropna()
    data = data.drop_duplicates()
    data.columns = data.columns.str.lower()
    print(data.head())
    return data

def load_data(data, table_name): 
    try: 
        connection = mysql.connector.connect(
            host= host,
            user=user,
            password= password, 
            database = database
        )
        print('conexion exitosa')
    except Error as e:
        print(e)
    
    cursor = connection.cursor()
    #cursor.execute(f'create table if not exists {table_name}')
    cursor.close()


def proceso_etl():
    
    clientes = extract_data('files/clientes.csv')
    ventas = extract_data('files/ventas.csv')

    clientes_transformed = transform_data(clientes)
    ventas_transformed =  transform_data(ventas)
    
    load_data(clientes_transformed, 'clientes')
    load_data(ventas_transformed, 'ventas')


proceso_etl()
# Out:
# Extrayendo data de files/clientes.csv
#    id  first_name last_name                         email  gender  \
# 0   1       Cheri  Dunsmore      cdunsmore0@instagram.com  Female
# 1   2        Hunt  Bartomeu         hbartomeu1@nsw.gov.au    Male
# 2   3  Michaeline   Paynton            mpaynton2@narod.ru  Female
# 3   4      Filmer    Eirwin            feirwin3@intel.com     NaN
# 4   5      Tanhya   Lubbock  tlubbock4@huffingtonpost.com  Female
#
#                           City Country                   Address
# 0            Palma De Mallorca   Spain  076 Rockefeller Crossing
# 1                         Lugo   Spain        0046 Utah Junction
# 2                          NaN   Spain          0 Corry Crossing
# 3                         Leon   Spain       5 American Ash Road
# 4  Hospitalet De Llobregat, L'   Spain         9289 Merry Circle
# Extrayendo data de files/ventas.csv
#    ID_Cliente ID_Producto Fecha_Venta  Cantidad  Total
# ...

# %% [markdown]
# proyecto:
#     - src
#         - jupyters
#         - data
#             - file1
#             - file2
#         - funciones.py
#         - bd.py(creacion bases, insercion, modificascion)
#         - queries_bd.py (definicion de las queries)
#     main.py
